# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/strathspey_combined.csv')
df2 = pd.read_csv('data/edinburgh-daytime-cleaned.csv')

merged_df = pd.merge(df1, df2, left_on='date', right_on='Date', how='inner')

# %%
merged_df.head()
# Out:
#          date temp_mean temp_min temp_max  rain_mm pressure_early  \
# 0  2011-12-01       3.6     -0.4      4.6      0.0            995
# 1  2011-12-02       2.6     -1.5      7.5      5.5           1003
# 2  2011-12-03       2.4      0.4      4.4      6.0            986
# 3  2011-12-04      -1.6     -0.9      0.4      3.7            988
# 4  2011-12-05      -1.6     -4.2      0.2      2.9            994
#
#   pressure_late wind_mean wind_max wind_dir  ...    Length Difference  \
# 0          1004       4.1       36      SSW  ...  07:25:45       2:37
# 1           983       6.5       36      SSW  ...  07:23:13       2:31
# 2           988       9.5       46      SSW  ...  07:20:48       2:25
# 3           992       4.5       22      SSW  ...  07:18:29       2:18
# 4           998       2.8       17      SSW  ...  07:16:17       2:12
#
#       Start       End   Start.1     End.1   Start.2     End.2   Time  Mil. km
# 0  06:00:00  18:02:00  06:45:00  17:17:00  07:33:00  16:29:00  12:01  147.520
# 1  06:02:00  18:01:00  06:46:00  17:16:00  07:34:00  16:28:00  12:02  147.495
# 2  06:03:00  18:01:00  06:48:00  17:16:00  07:36:00  16:28:00  12:02  147.471
# 3  06:04:00  18:00:00  06:49:00  17:15:00  07:37:00  16:27:00  12:02  147.447
# 4  06:05:00  18:00:00  06:50:00  17:15:00  07:39:00  16:27:00  12:03  147.425
#
# [5 rows x 24 columns]
