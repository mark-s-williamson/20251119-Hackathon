# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/strathspey_combined.csv')
df2 = pd.read_csv('data/edinburgh-daytime-cleaned.csv')

merged_df = pd.merge(df1, df2, on='date', how='inner')

# %%
merged_df.head()
# Out:
#          date temp_mean temp_min temp_max  rain_mm pressure_early  \
# 0  2011-12-01       3.6     -0.4      4.6      0.0            995
# 1  2011-12-02       2.6     -1.5      7.5      5.5           1003
# 2  2011-12-03       2.4      0.4      4.4      6.0            986
# 3  2011-12-04      -1.6     -0.9      0.4      3.7            988
# 4  2011-12-05      -1.6     -4.2      0.2      2.9            994
#
#   pressure_late wind_mean wind_max wind_dir  ...        daylength  \
# 0          1004       4.1       36      SSW  ...  0 days 07:25:45
# 1           983       6.5       36      SSW  ...  0 days 07:23:13
# 2           988       9.5       46      SSW  ...  0 days 07:20:48
# 3           992       4.5       22      SSW  ...  0 days 07:18:29
# 4           998       2.8       17      SSW  ...  0 days 07:16:17
#
#   daylength_difference  at_start    at_end  nt_start    nt_end  ct_start  \
# 0                  NaN  06:00:00  18:02:00  06:45:00  17:17:00  07:33:00
# ...

# %%
merged_df_2012 = merged_df[pd.to_datetime(merged_df['date']).dt.year == 2012]

# %%
merged_df_2012['date'] = pd.to_datetime(merged_df_2012['date'], errors='coerce')
# Out:
# C:\Users\marks\AppData\Local\Temp\ipykernel_1026760\2251191525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df_2012['date'] = pd.to_datetime(merged_df_2012['date'], errors='coerce')

# %%
merged_df_2012['date'].dt.year.unique().tolist()
# Out:
# [2012]

# %%
merged_df_2012.head(5)
# Out:
#           date temp_mean temp_min temp_max  rain_mm pressure_early  \
# 31  2012-01-01       2.5        3      3.4      0.3            988
# 32  2012-01-02      -0.1     -0.1      3.4      6.6            960
# 33  2012-01-03       1.6      0.5      3.2      6.4            960
# 34  2012-01-04       1.4      0.5      3.1     15.4           1000
# 35  2012-01-05       0.7     -1.4      1.9      2.7            993
# ..         ...       ...      ...      ...      ...            ...
# 390 2012-12-27       0.2     -4.3      4.8      0.2           1004
# 391 2012-12-28       6.3     -1.4     12.2      0.0            997
# 392 2012-12-29       5.8      4.5      7.5      0.0            985
# 393 2012-12-30         2      0.2        9      3.3            986
# 394 2012-12-31       4.7      1.2      8.1      0.5            976
#
#     pressure_late wind_mean wind_max wind_dir  ...        daylength  \
# 31            991       6.7       30      SSW  ...  0 days 07:04:53
# ...
